# %% [markdown]
# # Week 11 - Final Exam

# %% [markdown]
# Created by Junyeong Ahn (Jan, 2025)

# %% [markdown]
# Thus far, we've studied Python basics through ..
#
# - Week 1: Python Data Types #1
#
# - Week 2: Python Data Types #2
#
# - Week 3: Condition Sentences and Loop
#
# - Week 4: Variable and Function
#
# - Week 5: Mid Exam
#
# - Week 5.5 : Recap Week
#
# - Week 6: Class and Built-In Functions
#
# - Week 7: Python Standard Libraries
#
# - Week 8: se Expression #2 & Advanced Topics #1 - Iterators and Closure
#
# - Week 9: Advanced Topics #2 - Decorator, Comprehensions and Lambda Expressions
#
# - Week 10: Getting Ready to Level Up

# %% [markdown]
# 우리는 다음 주, 프로그래머들의 진검승부처인 **Data Structure Basics**과 **Algorithm Basics**에 들어갈 것이다.

# %% [markdown]
# ## 🖥️ Python Basics - Final Exam 🖥️

# %% [markdown]
# 65점 이상 : Pass & no homework
#
# 65점 미만 : Practice problem 5개 homework

# %% [markdown]
# - 총 5문제로 되어있으며, 제한 시간은 90분이다.
#
# - Partial score가 있으니, 최대한 정답에 가까운 과정까지라도 작성하도록 노력해야 한다.
#
# - 풀지 못한 문제는, homework가 되는 무시무시한 일이 벌어진다 !! (하지만 다 풀면 homework는 없다)
#
# - **어렵거나 복잡해도, 포기하지 않고 열심히 도전해준다면, 열심히 문제를 만든 Justin이 매우 뿌듯해 할 것이다.**

# %% [markdown]
# ## Problem 1. (20 pts)

# %% [markdown]
# ### Problem 1. A. (10 pts)

# %% [markdown]
# 다음과 같이 학생들의 이름과 점수로 이루어진 dictionary가 주어진다:
#
# ```python
# {"Alice": 88, "Bob": 72, "Charlie": 95, "Diana": 88}
# ```
#
# 이 때, 다음과 같이 '**점수를 기준으로**, 학생 이름을 오름차순으로 정렬한 list를 return'하는 function을 작성하시오:
#
#
# ```python
# ['Bob', 'Alice', 'Diana', 'Charlie']
# ```

# %% [markdown]
# Student's solution

# %%
# Write your code

def names_sorted_by_scores(input_dict):
    a = (list(input_dict.items()))
    b = (list(input_dict.values()))
    return sorted(b)



    # return ...


# TEST CODE #


names_and_scores = {"Alice": 88, "Bob": 72, "Charlie": 95, "Diana": 88}
print(names_sorted_by_scores(names_and_scores))
# Out:
# [72, 88, 88, 95]

# %% [markdown]
# ### Problem 2. B. (10 pts)

# %% [markdown]
# 다음과 같은 패턴을 print하시오.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Student's solution

# %%
# Write your code
a = -1
while a < 17:
    a += 2
    print (' ' * (8 - (int((a - 1) / 2))), end = '')
    print ('*' * a)
# Out:
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************
# *****************

# %% [markdown]
# ## Problem 2. (20 pts)

# %% [markdown]
# (예시로) 다음과 같이 평범한nested list이지만 시각적으로 grid(격자)처럼 보이도록 띄어쓰기가 된 5 X 5 격자 크기의 list가 주어진다:
#
# ```python
# [[1, 71, 20, 71, 20],
#  [12, 1, 15, 71, 20,],
#  [92, 31, 20, 12, 225],
#  [14, 123, 36, 42, 72],
#  [25, 262, 283, 92, 19]]
# ```
#
# 이 때, 이 list 내에서 시각적으로 한중간에 있는(위의 예시에서는 ```20```) 원소를 기준으로 **십자가 모양**으로 걸쳐져있는 총 9개의 숫자 중에서, 한중간의 숫자보다 큰 숫자는 총 몇 개인지 구하는 코드를 작성하시오.

# %% [markdown]
# Hint: Nested list의 원소에는 indexing도 이중으로 사용해서 접근해야 한다.

# %% [markdown]
# Note: 위치적으로 십자가 모양에 있는 것들을 패턴에 따라 검사해야 하며, 모든 십자가 위치를 수동으로 indexing하여 세는 것은 0점 처리한다.

# %% [markdown]
# Student's solution

# %%
my_list = [[1, 71, 20, 71, 20],
 [12, 1, 15, 71, 20,],
 [92, 31, 20, 12, 225],
 [14, 123, 36, 42, 72],
 [25, 262, 283, 92, 19]]

# Write your solution
a = []
c = 0
for x in range(0,2):
    a.append(my_list[x][2])
    a.append(my_list[2][x])
for y in range(3, 5):
    a.append(my_list[y][2])
    a.append(my_list[2][y])
b = (my_list[2][2])
for i in a:
    if i > b:
        c += 1
    else:
        continue
print(c)
# Out:
# 5

# %% [markdown]
# ## Problem 3. (20 pts)

# %% [markdown]
# ### Problem 3. A. (10 pts)

# %% [markdown]
# **MultiFuncs**라는 이름의 class를 만들어보자.
#
# MultiFuncs는, 다음과 같은 성질을 지녀야 한다:
#
# <br>
#
# - 단 하나의 method, FourCal()을 가진다.
#
# - MultiFuncs class는 constructor(생성자)를 이용하여, object 생성과 동시에 class의 ()내에 입력된 숫자 두 개를 객체 변수로 지정할 수 있어야 한다.
#
# - FourCal()은, object의 생성과 동시에 객체 변수가 된 두 숫자에 대해서 사칙 연산의 결과를 모두 print 해주는 method이다.
#
# <br>
# <br>
#
# Hint : Method를 만들 때마다 self도 parameter로 넣어줘야한다는 점을 명심하자. 또한 self는 입력된 두 숫자를 객체 변수로 만들 때도 사용되어야 한다.
#
#
# <br><br>
#
# 즉, 다음과 같이 작성했을 때 이러한 결과가 나와야 한다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Note : print( ~, end = ' ') 옵션을 활용하지 않으면, 부분 점수에 감점이 있다.

# %% [markdown]
# Student's solution

# %%
# Wrtie your code
class MultiFuncs:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    
    def FourCal(self):
        c = self.a + self. b
        d = self.a - self.b
        e = self.a * self.b
        f = self.a / self.b
        print(f'덧셈의 결과는 {c}입니다.')
        print(f'뺄셈의 결과는 {d}입니다.')
        print(f'곱셈의 결과는 {e}입니다.')
        print(f'나눗셈의 결과는 {f}입니다.')

obj = MultiFuncs(50, 10)
obj.FourCal()
# Out:
# 덧셈의 결과는 60입니다.
# 뺄셈의 결과는 40입니다.
# 곱셈의 결과는 500입니다.
# 나눗셈의 결과는 5.0입니다.

# %% [markdown]
# ### Problem 3. B. (10 pts)

# %% [markdown]
# 위에서 정의된 MultiFuncs class를 보다보니, 주어진 숫자들의 최대값을 찾는 Maxima method와, 평균을 찾아주는 Mean method를 추가하고 싶어졌다.
#
# 위의 기능들이 추가된 새로운 class FultiFuncs2를 작성하시오.
# <br><br>
#
# - MultiFuncs의 method를 복사/붙여넣기할 수 없고, 상속해야 한다.
#
# - 새롭게 추가된 두 methods는 결과를 print() 해주어야 한다.
#
# - Fourcal method까지 합쳐서 총 세 개의 기능을 할 수 있어야 한다.
#
# - You know, manual counting is always banned!
#
# <br><br>
# 즉, 다음과 같이 작성했을 때 이러한 결과가 나와야 한다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Student's solution

# %%
class MultiFuncs2(MultiFuncs):
    def Maxima(self, a):
        g = max(a)
        print(f'주어진 리스트의 최대값은 {g}입니다.')
    def Mean(self, a):
        h = sum(a)/len(a)
        print(f'주어진 리스트의 평균은 {h}입니다.')
obj2 = MultiFuncs2(30, 4)
obj2.FourCal()
obj2.Maxima([10, 90, 65, 25, 40])
obj2.Mean([70, 10, 25, 5, 44, 1.5])
# Out:
# 덧셈의 결과는 34입니다.
# 뺄셈의 결과는 26입니다.
# 곱셈의 결과는 120입니다.
# 나눗셈의 결과는 7.5입니다.
# 주어진 리스트의 최대값은 90입니다.
# 주어진 리스트의 평균은 25.916666666666668입니다.

# %% [markdown]
# ## Problem 4. (20 pts)

# %% [markdown]
# 프로그래머의 기본 소양은, '당신이 무엇을 작성했는가'를 타인에게 설명할 수 있어야 한다는 것이다. 당신의 작업물 자체로는 위대할지 모르지만, 만약 타인이 이해할 수도 없고 당신이 설명할 수도 없는 코드라면 그 누구도 그를 재사용하거나 발전시키지 않을 것이다. 즉, 죽은 1회용 작업물이 된다는 것이다.
#
# 이전까지 당신에게 프로그래밍을 맡긴 '나'는 프로그래밍에 대해 이미 잘 알고 있는 사람이다. 하지만, 실제 고객의 의뢰는 그렇게 구체적이지 못하다.
#
# <br><br>
# 즉, '원하는 것'을 적당히 말했을 때, 당신이 그가 흡족하게끔 '잘' 작성해야 한다는 말이다. 다른 말로는 방식, 형식 모두 정해져있지 않다는 것이다. 이 때, 어떤 은행원이 당신에게 꽤 추상적으로 의뢰를 맡겨왔다.

# %% [markdown]
# 간단한 은행 계좌 시스템을 설계하고 구현해보자 (15 pts).
#
# - BankAccount 클래스를 작성하시오.
# - 각 object는 '계좌 소유자의 이름'과 '초기 잔액'을 입력받아야 합니다.
#
# - 다음 기능을 포함해야 합니다:
#     - 잔액 확인 (check_balance)
#     - 입금 (deposit)
#     - 출금 (withdraw, 잔액이 부족하면 에러 메시지 출력)
#     - 거래 내역 기록 및 출력 (transaction_history)
# <br><br>
#
# 구현한 뒤에는, 객체를 만들고 각 method를 적절히 사용하여 은행원이 당신의 구현을 확인할 수 있도록 사용 예시를 작성하시오 (5 pts).

# %% [markdown]
# Note : Constructor를 사용하지 않으면 3점 감점.

# %% [markdown]
# Student's solution

# %%
# Write your code

class BankAccount:
    def __init__(self, his_name, firstmoney, comingmoney, goingmoney):
        self.his_name = his_name
        self.firstmoney = firstmoney
        self.comingmoney = comingmoney
        self.goingmoney = goingmoney
    def name(self):
        self.his_name
    def check_balance(self):
        self.firstmoney + self.comingmoney - self.goingmoney
    def deposit(self):
        self.comingmoney
    def withdraw(self):
        self.goingmoney

# %% [markdown]
# ## Problem 5. (20 pts)

# %% [markdown]
# (예시로) 다음과 같이, 각 원소를 tuple로 갖는 list가 주어진다:
#
# ```python
# [ ('2', '4'), ('2', '1'), ('1', '6'), ('8', '1'), ('3', '8'), ('8', '1') ]
# ```
#
# 이 때,
#
# ```python
# [('1', '6'), ('8', '1')]
# ```
#
# 와 같이, 1. 중복 없이, 2. 'tuple의 각 숫자를 이어붙인 것이 제곱수인 tuple만을 담은 list'를 return하는 function을 작성하시오.

# %% [markdown]
# Note1: 주어진 코드에서 최대 두 줄의 코드만 추가적으로 작성하라. (만족시 +5 pts)
#
# Note2: List comprehension을 사용하라.  (불만족시 -5 pts)

# %% [markdown]
# Student's solution

# %%
print('[', end = '')
def unique_squares(nums):
    for i in range(0,len(nums)):
        if ((eval(nums[i][0]) * 10) + (eval(nums[i][1]))) > 10:
            print(nums[i],end='')
        else:
            pass
    print(']')

# 이 return 라인 또한 2줄 제한에 포함된다. 


# Test Code #

nums = [('9', '1'), ('3', '6'), ('4', '9'), ('2', '5'), ('1', '4'), ('7', '2'), ('4', '9')]
print(unique_squares(nums))
# Out:
# [('9', '1')('3', '6')('4', '9')('2', '5')('1', '4')('7', '2')('4', '9')]
# None
